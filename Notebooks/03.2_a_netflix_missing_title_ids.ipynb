# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz

# %% [markdown]
# ## Find missing IMDB IDs for Netflix Data
#
# #### Goals
#
# - Find missing titles from original merge.
# - Find missing titles on IMDB using fuzzywuzzy.
#
# ### 1. Import data

# %%
netflix = pd.read_csv("../Data/netflix_shows.csv")

# %%
netflix_ids = pd.read_pickle("../Data/netflix_ids.pkl")

# %%
netflix_missing = pd.read_pickle("../Data/netflix_missing.pkl")

# %% [markdown]
# ### 2. Compare length of values of oringal list vs new ones
#
# We will compare the number of rows from the original netflix data frame and the sum of the missing titles and the netflix ids.

# %%
len(netflix)
# Out:
# 1915

# %%
len(netflix_ids) + len(netflix_missing)
# Out:
# 1909

# %%
netflix["show"].nunique()
# Out:
# 1909

# %% [markdown]
# 6 values are missing but when looking at unique values on the original data frame, we get the same result. This means that there must be some repeated titles which may be from different years. We will make a value count for the show column in the original netflix data frame.

# %%
netflix["show"].value_counts().head(6)
# Out:
# The Good Cop        2
# Inspector Gadget    2
# Danger Mouse        2
# Maniac              2
# Charmed             2
# The Code            2
# Name: show, dtype: int64

# %% [markdown]
# We will look at each of them and add them the netflix missing data frame.

# %%
netflix[netflix["show"] == "The Code"]
# Out:
#          show  year rating  imdb rotten_tomatoes
# 483  The Code  2011    NaN   7.4            100%
# 637  The Code  2014    NaN   7.4             NaN

# %%
netflix_ids[netflix_ids["show"] == "The Code"]
# Out:
#          show  year rating  imdb rotten_tomatoes     tconst     titleType  \
# 396  The Code  2011    NaN   7.4            100%  tt2060305  tvMiniSeries
#
#     primaryTitle originalTitle  isAdult  ...  runtimeMinutes       genres  \
# 396     The Code      The Code      0.0  ...              \N  Documentary
#
#     titleId ordering title  region language types attributes isOriginalTitle
# 396     NaN      NaN   NaN     NaN      NaN   NaN        NaN             NaN
#
# [1 rows x 22 columns]

# %%
netflix_missing = netflix_missing.append(netflix[(netflix["show"] == "The Code") & (netflix["year"] == 2014)])

# %%
netflix[netflix["show"] == "Maniac"]
# Out:
#         show  year rating  imdb rotten_tomatoes
# 138   Maniac  2018    16+   7.8             85%
# 1244  Maniac  2015    NaN   7.0             NaN

# %%
netflix_ids[netflix_ids["show"] == "Maniac"]
# Out:
#        show  year rating  imdb rotten_tomatoes     tconst     titleType  \
# 117  Maniac  2018    16+   7.8             85%  tt5580146  tvMiniSeries
#
#     primaryTitle originalTitle  isAdult  ...  runtimeMinutes  \
# 117       Maniac        Maniac      0.0  ...              40
#
#                   genres titleId ordering title  region language types  \
# 117  Comedy,Drama,Sci-Fi     NaN      NaN   NaN     NaN      NaN   NaN
#
#     attributes isOriginalTitle
# 117        NaN             NaN
#
# [1 rows x 22 columns]

# %%
netflix_missing = netflix_missing.append(netflix[(netflix["show"] == "Maniac") & (netflix["year"] == 2015)])

# %%
netflix[netflix["show"] == "Danger Mouse"]
# Out:
#               show  year rating  imdb rotten_tomatoes
# 825   Danger Mouse  1981     7+   7.4             NaN
# 1197  Danger Mouse  2015    all   7.1             NaN

# %%
netflix_ids[netflix_ids["show"] == "Danger Mouse"]
# Out:
#              show  year rating  imdb rotten_tomatoes     tconst titleType  \
# 621  Danger Mouse  1981     7+   7.4             NaN  tt0081848  tvSeries
#
#      primaryTitle originalTitle  isAdult  ...  runtimeMinutes  \
# 621  Danger Mouse  Danger Mouse      0.0  ...              25
#
#                       genres titleId ordering title  region language types  \
# 621  Animation,Comedy,Family     NaN      NaN   NaN     NaN      NaN   NaN
#
#     attributes isOriginalTitle
# 621        NaN             NaN
#
# [1 rows x 22 columns]

# %%
netflix_missing = netflix_missing.append(netflix[(netflix["show"] == "Danger Mouse") & (netflix["year"] == 2015)])

# %%
netflix[netflix["show"] == "Charmed"]
# Out:
#         show  year rating  imdb rotten_tomatoes
# 134  Charmed  1998    16+   7.1             75%
# 656  Charmed  2018    16+   4.5             NaN

# %%
netflix_ids[netflix_ids["show"] == "Charmed"]
# Out:
#         show  year rating  imdb rotten_tomatoes     tconst titleType  \
# 113  Charmed  1998    16+   7.1             75%  tt0158552  tvSeries
#
#     primaryTitle originalTitle  isAdult  ...  runtimeMinutes  \
# 113      Charmed       Charmed      0.0  ...              42
#
#                     genres titleId ordering title  region language types  \
# 113  Drama,Fantasy,Mystery     NaN      NaN   NaN     NaN      NaN   NaN
#
#     attributes isOriginalTitle
# 113        NaN             NaN
#
# [1 rows x 22 columns]

# %%
netflix_missing = netflix_missing.append(netflix[(netflix["show"] == "Charmed") & (netflix["year"] == 2018)])

# %%
netflix[netflix["show"] == "The Good Cop"]
# Out:
#               show  year rating  imdb rotten_tomatoes
# 589   The Good Cop  2018    16+   7.0             50%
# 1354  The Good Cop  2015    NaN   7.5             NaN

# %%
netflix_ids[netflix_ids["show"] == "The Good Cop"]
# Out:
#              show  year rating  imdb rotten_tomatoes     tconst titleType  \
# 470  The Good Cop  2018    16+   7.0             50%  tt7183074  tvSeries
#
#      primaryTitle originalTitle  isAdult  ...  runtimeMinutes  \
# 470  The Good Cop  The Good Cop      0.0  ...              60
#
#                  genres titleId ordering title  region language types  \
# 470  Comedy,Crime,Drama     NaN      NaN   NaN     NaN      NaN   NaN
#
#     attributes isOriginalTitle
# 470        NaN             NaN
#
# [1 rows x 22 columns]

# %%
netflix_missing = netflix_missing.append(netflix[(netflix["show"] == "The Good Cop") & (netflix["year"] == 2015)])

# %%
netflix[netflix["show"] == "Inspector Gadget"]
# Out:
#                   show  year rating  imdb rotten_tomatoes
# 606   Inspector Gadget  1983     7+   6.8             NaN
# 1466  Inspector Gadget  2015    all   4.3             NaN

# %%
netflix_ids[netflix_ids["show"] == "Inspector Gadget"]
# Out:
#                  show  year rating  imdb rotten_tomatoes     tconst titleType  \
# 482  Inspector Gadget  1983     7+   6.8             NaN  tt0085033  tvSeries
#
#          primaryTitle     originalTitle  isAdult  ...  runtimeMinutes  \
# 482  Inspector Gadget  Inspector Gadget      0.0  ...              30
#
#                          genres titleId ordering title  region language types  \
# 482  Action,Adventure,Animation     NaN      NaN   NaN     NaN      NaN   NaN
#
#     attributes isOriginalTitle
# 482        NaN             NaN
#
# [1 rows x 22 columns]

# %%
netflix_missing = netflix_missing.append(netflix[(netflix["show"] == "Inspector Gadget") & (netflix["year"] == 2015)])

# %%
len(netflix_missing) + len(netflix_ids)
# Out:
# 1915

# %% [markdown]
# Now we got the same values from the original tv shows and the new data frames.

# %%
netflix_missing = netflix_missing.reset_index(drop=True)

# %% [markdown]
# ### 3. Find missing titles using fuzzywuzzy
#
# We will first create a list for missing shows.

# %%
netflix_shows_missing = [show for show in netflix_missing["show"]]

# %%
len(netflix_shows_missing)
# Out:
# 204

# %%
imdb = pd.read_pickle(path + "Data/imdb_tv_all.pkl")

# %% [markdown]
# We will create a function to find the most similar title on the imdb title basics file.

# %%
imdb_titles = [title for title in imdb["primaryTitle"]]

# %%
def find_shows(show):
    matches = []

    for title in imdb_titles:
        # compute ratio and remove case-sensitivity
        ratio = fuzz.ratio(title.lower(), show.lower())

        # add all matches to list with ratio > 60
        if ratio >= 60:
            matches.append((title, show, ratio))
    
    # return none if there was no match found
    if len(matches) == 0:
        return None
    return sorted(matches, key=lambda x: x[2], reverse=True)[0][0]

# %% [markdown]
# We will make a test with the first value from the missing shows list.

# %%
netflix_shows_missing[0]
# Out:
# 'YOU'

# %%
find_shows(netflix_shows_missing[0])
# Out:
# 'You'

# %% [markdown]
# We will now create a new column with the matched imdb titles.

# %%
netflix_missing["imdb_titles"] = netflix_missing["show"].apply(lambda x: find_shows(x))

# %%
netflix_missing.head(10)
# Out:
#                                                 show  year rating  imdb  \
# 0                                                YOU  2018    18+   7.8
# 1                             Marvel's Jessica Jones  2015    18+   8.0
# 2                                             HAPPY!  2017    18+   8.2
# 3                                           Haikyu!!  2014    16+   8.7
# 4                                    F is for Family  2015    18+   8.0
# 5                                              GHOUL  2018    18+   7.1
# 6                     Time: The Kalief Browder Story  2017    16+   8.5
# 7                anohana: The Flower We Saw That Day  2011    16+   8.2
# 8  My Next Guest Needs No Introduction With David...  2018    18+   7.9
# 9                                   Valhalla Murders  2019    18+   7.1
#
#   rotten_tomatoes                                        imdb_titles
# 0             91%                                                You
# 1             83%                                      Jessica Jones
# 2             84%                                             Happy!
# 3             NaN                                          Haikyuu!!
# 4             86%                                    F Is for Family
# 5             83%                                              Ghoul
# 6            100%                     TIME: The Kalief Browder Story
# 7             NaN                Anohana: The Flower We Saw That Day
# 8             83%  My Next Guest Needs No Introduction with David...
# 9             NaN                               The Valhalla Murders

# %% [markdown]
# From the first 10 missing titles we can see that our function did a good job, we will now take a look at the titles that weren't found a match.

# %%
netflix_missing[netflix_missing["imdb_titles"].isna()]
# Out:
#                                      show  year rating  imdb rotten_tomatoes  \
# 39            Yunus Emre: Aşkın Yolculuğu  2015    NaN   7.8             NaN
# 102  Bangkok รัก Stories 2 ตอน ไม่เดียงสา  2018    NaN   6.9             NaN
# 142                                 Тобот  2010    NaN   6.2             NaN
# 151                                   阳关道  2018    NaN   3.2             NaN
#
#     imdb_titles
# 39         None
# 102        None
# 142        None
# 151        None

# %%
netflix_missing = netflix_missing[~netflix_missing["imdb_titles"].isna()]

# %% [markdown]
# Since we have only 4 titles and they are in another language, we will remove them from our data.
#
# ### 4. Merge IMDB IDs
#
# We will still merge on the year, in order to be sure that we are not merging a remake or a similar title.

# %%
netflix_missing = netflix_missing.merge(imdb, how="left", left_on=["imdb_titles", "year"], right_on=["primaryTitle", "startYear"])

# %%
netflix_missing.head()
# Out:
#                      show  year rating  imdb rotten_tomatoes      imdb_titles  \
# 0                     YOU  2018    18+   7.8             91%              You
# 1  Marvel's Jessica Jones  2015    18+   8.0             83%    Jessica Jones
# 2                  HAPPY!  2017    18+   8.2             84%           Happy!
# 3                Haikyu!!  2014    16+   8.7             NaN        Haikyuu!!
# 4         F is for Family  2015    18+   8.0             86%  F Is for Family
#
#       tconst titleType     primaryTitle    originalTitle  isAdult  startYear  \
# 0  tt7335184  tvSeries              You              You      0.0     2018.0
# 1  tt2357547  tvSeries    Jessica Jones    Jessica Jones      0.0     2015.0
# 2  tt2452242  tvSeries           Happy!           Happy!      0.0     2017.0
# 3  tt3398540  tvSeries        Haikyuu!!        Haikyuu!!      0.0     2014.0
# 4  tt4326894  tvSeries  F Is for Family  F Is for Family      0.0     2015.0
#
#    endYear runtimeMinutes                  genres
# 0   2018.0             45     Crime,Drama,Romance
# 1   2015.0             56      Action,Crime,Drama
# 2   2017.0             60     Action,Comedy,Crime
# 3   2014.0             24  Animation,Comedy,Drama
# 4   2015.0             30  Animation,Comedy,Drama

# %% [markdown]
# We will now take a look at the titles who didn't find a match.

# %%
netflix_missing[netflix_missing["tconst"].isna()]
# Out:
#                                         show  year rating  imdb  \
# 15                                 WHAT / IF  2019    18+   6.3
# 20                                 K-Project  2012    18+   7.2
# 21                      Cooked With Cannabis  2020    18+   7.0
# 22                               El Chapulín  1972    all   8.5
# 24   Terrace House: Boys & Girls in the City  2015     7+   8.2
# ..                                       ...   ...    ...   ...
# 189                              Voice (OCN)  2017    NaN   NaN
# 191                          The Golden Path  2012    NaN   NaN
# 192                            The Underwear  2017    NaN   NaN
# 193                     Taste of the Country  2011    NaN   NaN
# 195                                   Maniac  2015    NaN   7.0
#
#     rotten_tomatoes                           imdb_titles tconst titleType  \
# 15              NaN                               What If    NaN       NaN
# 20              NaN                             B-Project    NaN       NaN
# 21              80%                      Coffee with Anna    NaN       NaN
# 22              NaN                              El Chapo    NaN       NaN
# 24              NaN  Terrace House Boys x Girls Next Door    NaN       NaN
# ..              ...                                   ...    ...       ...
# 189             NaN                       Voices 4 Oceans    NaN       NaN
# 191             NaN                        The Golden Bat    NaN       NaN
# 192             NaN                         The Undercard    NaN       NaN
# 193             NaN                  Heart of the Country    NaN       NaN
# 195             NaN                                Maniac    NaN       NaN
#
#     primaryTitle originalTitle  isAdult  startYear  endYear runtimeMinutes  \
# 15           NaN           NaN      NaN        NaN      NaN            NaN
# 20           NaN           NaN      NaN        NaN      NaN            NaN
# 21           NaN           NaN      NaN        NaN      NaN            NaN
# 22           NaN           NaN      NaN        NaN      NaN            NaN
# 24           NaN           NaN      NaN        NaN      NaN            NaN
# ..           ...           ...      ...        ...      ...            ...
# 189          NaN           NaN      NaN        NaN      NaN            NaN
# 191          NaN           NaN      NaN        NaN      NaN            NaN
# 192          NaN           NaN      NaN        NaN      NaN            NaN
# 193          NaN           NaN      NaN        NaN      NaN            NaN
# 195          NaN           NaN      NaN        NaN      NaN            NaN
#
#     genres
# 15     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 24     NaN
# ..     ...
# 189    NaN
# 191    NaN
# 192    NaN
# 193    NaN
# 195    NaN
#
# [85 rows x 15 columns]

# %% [markdown]
# We can see that most of this titles don't have a similar imdb titles, due to this, we will drop this columns also.

# %%
netflix_ids_new = netflix_missing[~netflix_missing["tconst"].isna()].reset_index(drop=True).drop_duplicates("tconst")

# %%
netflix_ids = netflix_ids.append(netflix_ids_new)

# %%
netflix_ids.head()
# Out:
#                show  year rating  imdb rotten_tomatoes     tconst titleType  \
# 0      Breaking Bad  2008    18+   9.5             96%  tt0903747  tvSeries
# 1   Stranger Things  2016    16+   8.8             93%  tt4574334  tvSeries
# 2          Sherlock  2010    16+   9.1             78%  tt1475582  tvSeries
# 3  Better Call Saul  2015    18+   8.7             97%  tt3032476  tvSeries
# 4        The Office  2005    16+   8.9             81%  tt0386676  tvSeries
#
#        primaryTitle     originalTitle  isAdult  ...                genres  \
# 0      Breaking Bad      Breaking Bad      0.0  ...  Crime,Drama,Thriller
# 1   Stranger Things   Stranger Things      0.0  ...  Drama,Fantasy,Horror
# 2          Sherlock          Sherlock      0.0  ...   Crime,Drama,Mystery
# 3  Better Call Saul  Better Call Saul      0.0  ...           Crime,Drama
# 4        The Office        The Office      0.0  ...                Comedy
#
#    titleId ordering title region  language types attributes isOriginalTitle  \
# 0      NaN      NaN   NaN    NaN       NaN   NaN        NaN             NaN
# 1      NaN      NaN   NaN    NaN       NaN   NaN        NaN             NaN
# 2      NaN      NaN   NaN    NaN       NaN   NaN        NaN             NaN
# 3      NaN      NaN   NaN    NaN       NaN   NaN        NaN             NaN
# 4      NaN      NaN   NaN    NaN       NaN   NaN        NaN             NaN
#
#   imdb_titles
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# We will now calculate the ratio of titles with an imdb id match and the original titles.

# %%
len(netflix_ids) / len(netflix)
# Out:
# 0.9535248041775457

# %% [markdown]
# This means that we will be using 95% of the original data.
#
# ### 5. Cleaning final data
#
# We will create a final data frame including:
# - show
# - year
# - rating
# - imdb
# - rotten_tomatoes
# - imdb_id
# - all data from title basics
#
# First, we will need to create the imdb_id column, this will have tconst and titleId values.

# %%
netflix_ids["imdb_id"] = np.where(netflix_ids["tconst"].isna(), netflix_ids["titleId"], netflix_ids["tconst"])

# %%
netflix_ids["imdb_id"].isna().value_counts()
# Out:
# False    1826
# Name: imdb_id, dtype: int64

# %% [markdown]
# This means we have all the IMDB IDs for all the titles in this final data frame. We will now remove columns that are not show, year, rating, imdb, rotten_tomatoes and imdb_id and merge again.

# %%
to_drop = [col for col in netflix_ids.columns if col not in ["show", "year", "rating", "imdb", "rotten_tomatoes", "imdb_id"]]

# %%
netflix_ids = netflix_ids.drop(columns=to_drop)

# %%
netflix_ids.head()
# Out:
#                show  year rating  imdb rotten_tomatoes    imdb_id
# 0      Breaking Bad  2008    18+   9.5             96%  tt0903747
# 1   Stranger Things  2016    16+   8.8             93%  tt4574334
# 2          Sherlock  2010    16+   9.1             78%  tt1475582
# 3  Better Call Saul  2015    18+   8.7             97%  tt3032476
# 4        The Office  2005    16+   8.9             81%  tt0386676

# %% [markdown]
# Now we will merge all data from title basics

# %%
netflix_ids = netflix_ids.merge(imdb, how="left", left_on="imdb_id", right_on="tconst")

# %%
netflix_ids.head()
# Out:
#                show  year rating  imdb rotten_tomatoes    imdb_id     tconst  \
# 0      Breaking Bad  2008    18+   9.5             96%  tt0903747  tt0903747
# 1   Stranger Things  2016    16+   8.8             93%  tt4574334  tt4574334
# 2          Sherlock  2010    16+   9.1             78%  tt1475582  tt1475582
# 3  Better Call Saul  2015    18+   8.7             97%  tt3032476  tt3032476
# 4        The Office  2005    16+   8.9             81%  tt0386676  tt0386676
#
#   titleType      primaryTitle     originalTitle  isAdult  startYear  endYear  \
# 0  tvSeries      Breaking Bad      Breaking Bad      0.0     2008.0   2008.0
# 1  tvSeries   Stranger Things   Stranger Things      0.0     2016.0   2016.0
# 2  tvSeries          Sherlock          Sherlock      0.0     2010.0   2010.0
# 3  tvSeries  Better Call Saul  Better Call Saul      0.0     2015.0   2015.0
# 4  tvSeries        The Office        The Office      0.0     2005.0   2005.0
#
#   runtimeMinutes                genres
# 0             49  Crime,Drama,Thriller
# 1             51  Drama,Fantasy,Horror
# 2             88   Crime,Drama,Mystery
# 3             46           Crime,Drama
# 4             22                Comedy

# %%
netflix_ids = netflix_ids.drop(columns="tconst")

# %% [markdown]
# ### 6. Export final data

# %%
# netflix_ids.to_pickle("../Data/netflix_final.pkl")
