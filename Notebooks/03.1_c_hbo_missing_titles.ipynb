# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz

path = "C:/Users/Admin/Documents/ironhack/streaming_service_recommender/"

# %% [markdown]
# ## Find missing IMDB IDs for HBO Data
#
# #### Goals
#
# - Find missing titles from original merge.
# - Find missing titles on IMDB using fuzzywuzzy.
#
# **NOTE: We will use the same process as in 03.1_a_netflix_missing_title_ids notebook**
#
# ### 1. Import data

# %%
hbo = pd.read_csv(path + "Data/hbo_shows.csv")

# %%
hbo_ids = pd.read_pickle(path + "Data/hbo_ids.pkl")

# %%
hbo_missing = pd.read_pickle(path + "Data/hbo_missing.pkl")

# %% [markdown]
# ### 2. Compare length of values of oringal list vs new ones
#
# We will compare the number of rows from the original amazon data frame and the sum of the missing titles and the amazon ids.

# %%
len(hbo)
# Out:
# 200

# %%
len(hbo_ids) + len(hbo_missing)
# Out:
# 197

# %%
hbo["show"].nunique()
# Out:
# 197

# %% [markdown]
# 3 values are missing but when looking at unique values on the original data frame, we get the same result. This means that there must be some repeated titles which may be from different years. We will make a value count for the show column in the original hbo data frame.

# %%
hbo["show"].value_counts().head(3)
# Out:
# High Maintenance        2
# The Electric Company    2
# Rome                    2
# Name: show, dtype: int64

# %% [markdown]
# We will look at each of them and add them the amazon missing data frame.

# %%
hbo[hbo["show"] == "The Electric Company"]
# Out:
#                      show  year rating  imdb rotten_tomatoes
# 122  The Electric Company  1971    all   8.1             NaN
# 156  The Electric Company  2009    NaN   7.3             NaN

# %%
hbo_ids[hbo_ids["show"] == "The Electric Company"]
# Out:
#                      show  year rating  imdb rotten_tomatoes     tconst  \
# 107  The Electric Company  1971    all   8.1             NaN  tt0066651
#
#     titleType          primaryTitle         originalTitle  isAdult  ...  \
# 107  tvSeries  The Electric Company  The Electric Company      0.0  ...
#
#      runtimeMinutes         genres titleId ordering title  region language  \
# 107              28  Comedy,Family     NaN      NaN   NaN     NaN      NaN
#
#     types attributes isOriginalTitle
# 107   NaN        NaN             NaN
#
# [1 rows x 22 columns]

# %%
hbo_missing = hbo_missing.append(hbo[(hbo["show"] == "The Electric Company") & (hbo["year"] == 2009)])

# %%
hbo[hbo["show"] == "High Maintenance"]
# Out:
#                  show  year rating  imdb rotten_tomatoes
# 50   High Maintenance  2016    18+   8.0             98%
# 111  High Maintenance  2012    18+   8.2             NaN

# %%
hbo_ids[hbo_ids["show"] == "High Maintenance"]
# Out:
#                 show  year rating  imdb rotten_tomatoes     tconst titleType  \
# 48  High Maintenance  2016    18+   8.0             98%  tt6078096  tvSeries
#
#         primaryTitle     originalTitle  isAdult  ...  runtimeMinutes  \
# 48  High Maintenance  High Maintenance      0.0  ...              30
#
#           genres titleId ordering title  region language types attributes  \
# 48  Comedy,Drama     NaN      NaN   NaN     NaN      NaN   NaN        NaN
#
#    isOriginalTitle
# 48             NaN
#
# [1 rows x 22 columns]

# %%
hbo_missing = hbo_missing.append(hbo[(hbo["show"] == "High Maintenance") & (hbo["year"] == 2012)])

# %%
hbo[hbo["show"] == "Rome"]
# Out:
#      show  year rating  imdb rotten_tomatoes
# 11   Rome  2005    18+   8.7             86%
# 181  Rome  2012    NaN   5.8             NaN

# %%
hbo_ids[hbo_ids["show"] == "Rome"]
# Out:
#     show  year rating  imdb rotten_tomatoes     tconst titleType primaryTitle  \
# 11  Rome  2005    18+   8.7             86%  tt0384766  tvSeries         Rome
#
#    originalTitle  isAdult  ...  runtimeMinutes                genres titleId  \
# 11          Rome      0.0  ...              52  Action,Drama,History     NaN
#
#    ordering title  region language types attributes isOriginalTitle
# 11      NaN   NaN     NaN      NaN   NaN        NaN             NaN
#
# [1 rows x 22 columns]

# %%
hbo_missing = hbo_missing.append(hbo[(hbo["show"] == "Rome") & (hbo["year"] == 2012)])

# %%
len(hbo_missing) + len(hbo_ids)
# Out:
# 200

# %% [markdown]
# Now we got the same values from the original tv shows and the new data frames.

# %%
hbo_missing = hbo_missing.reset_index(drop=True)

# %% [markdown]
# ### 3. Find missing titles using fuzzywuzzy
#
# We will first create a list for missing shows.

# %%
hbo_shows_missing = [show for show in hbo_missing["show"]]

# %%
len(hbo_shows_missing)
# Out:
# 18

# %%
imdb = pd.read_pickle(path + "Data/imdb_tv_all.pkl")

# %%
imdb_titles = [title for title in imdb["primaryTitle"]]

# %% [markdown]
# We will use the same function as on the netflix notebook, this time we will look for values with a ration higher than 80, since for HBO it is easy to see this because we have a small data frame.

# %%
def find_shows(show):
    matches = []

    for title in imdb_titles:
        # compute ratio and remove case-sensitivity
        ratio = fuzz.ratio(title.lower(), show.lower())

        # add all matches to list with ratio > 80
        if ratio >= 80:
            matches.append((title, show, ratio))
    
    # return none if there was no match found
    if len(matches) == 0:
        return None
    return sorted(matches, key=lambda x: x[2], reverse=True)[0][0]

# %% [markdown]
# We will now create a new column with the matched imdb titles.

# %%
hbo_missing["imdb_titles"] = hbo_missing["show"].apply(lambda x: find_shows(x))

# %%
hbo_missing
# Out:
#                                                  show  year rating  imdb  \
# 0                                    Jonah From Tonga  2014    NaN   7.1
# 1   We Can Be Heroes: Finding The Australian of th...  2005    18+   8.1
# 2                                        Magnifica 70  2015    16+   7.8
# 3                             The Shop: Uninterrupted  2018    18+   6.6
# 4                                              Arliss  1996    NaN   7.0
# 5                                            Epitaphs  2004    18+   7.9
# 6                                   VICE News Tonight  2016    16+   8.3
# 7                                 When Shall We Kiss?  2011    NaN   7.9
# 8                                           Todxs Nos  2020    NaN   5.4
# 9                                          El Pionero  2019    16+   7.3
# 10                                           Sex On//  2015    18+   5.8
# 11                                             KREMEN  2017    NaN   6.4
# 12                                      Destino Rusia  2018    NaN   8.1
# 13                                               SeNT  2017    NaN   5.6
# 14               HBO Latino Presents: A Tiny Audience  2019    NaN   NaN
# 15                               The Electric Company  2009    NaN   7.3
# 16                                   High Maintenance  2012    18+   8.2
# 17                                               Rome  2012    NaN   5.8
#
#    rotten_tomatoes           imdb_titles
# 0              80%      Jonah from Tonga
# 1              NaN                  None
# 2              NaN          Magnífica 70
# 3              NaN                  None
# 4              NaN                  None
# 5              NaN               Epitaph
# 6              NaN     Vice News Tonight
# 7              NaN     When Will We Kiss
# 8              NaN             Todxs Nós
# 9              NaN          El Camionero
# 10             NaN             Sex on //
# 11             NaN                Kremen
# 12             NaN    Destino Rusia 2018
# 13             NaN                  Sent
# 14             NaN                  None
# 15             NaN  The Electric Company
# 16             NaN      High Maintenance
# 17             NaN                  Rome

# %% [markdown]
# We will remove the null values for imdb titles, this accounts for 2% of the data.

# %%
hbo_missing = hbo_missing[~hbo_missing["imdb_titles"].isna()].reset_index(drop=True)

# %% [markdown]
# ### 4. Merge IMDB IDs
#
# We will still merge on the year, in order to be sure that we are not merging a remake or a similar title.

# %%
hbo_missing = hbo_missing.merge(imdb, how="left", left_on=["imdb_titles", "year"], right_on=["primaryTitle", "startYear"])

# %% [markdown]
# We will separate the missing titles that were not matched.

# %%
hbo_missing_2 = hbo_missing[hbo_missing["tconst"].isna()].reset_index(drop=True)

# %%
hbo_missing_2
# Out:
#                    show  year rating  imdb rotten_tomatoes  \
# 0              Epitaphs  2004    18+   7.9             NaN
# 1   When Shall We Kiss?  2011    NaN   7.9             NaN
# 2            El Pionero  2019    16+   7.3             NaN
# 3              Sex On//  2015    18+   5.8             NaN
# 4                KREMEN  2017    NaN   6.4             NaN
# 5                  SeNT  2017    NaN   5.6             NaN
# 6  The Electric Company  2009    NaN   7.3             NaN
#
#             imdb_titles tconst titleType primaryTitle originalTitle  isAdult  \
# 0               Epitaph    NaN       NaN          NaN           NaN      NaN
# 1     When Will We Kiss    NaN       NaN          NaN           NaN      NaN
# 2          El Camionero    NaN       NaN          NaN           NaN      NaN
# 3             Sex on //    NaN       NaN          NaN           NaN      NaN
# 4                Kremen    NaN       NaN          NaN           NaN      NaN
# 5                  Sent    NaN       NaN          NaN           NaN      NaN
# 6  The Electric Company    NaN       NaN          NaN           NaN      NaN
#
#    startYear  endYear runtimeMinutes genres
# 0        NaN      NaN            NaN    NaN
# 1        NaN      NaN            NaN    NaN
# 2        NaN      NaN            NaN    NaN
# 3        NaN      NaN            NaN    NaN
# 4        NaN      NaN            NaN    NaN
# 5        NaN      NaN            NaN    NaN
# 6        NaN      NaN            NaN    NaN

# %% [markdown]
# We will also remove this shows from the analysis since we cannot verify it is the same show due to the years, and some of them don't have a matching title.

# %%
hbo_missing = hbo_missing[~hbo_missing["tconst"].isna()]

# %%
hbo_missing = hbo_missing.reset_index(drop=True)

# %%
hbo_missing
# Out:
#                 show  year rating  imdb rotten_tomatoes         imdb_titles  \
# 0   Jonah From Tonga  2014    NaN   7.1             80%    Jonah from Tonga
# 1       Magnifica 70  2015    16+   7.8             NaN        Magnífica 70
# 2  VICE News Tonight  2016    16+   8.3             NaN   Vice News Tonight
# 3          Todxs Nos  2020    NaN   5.4             NaN           Todxs Nós
# 4      Destino Rusia  2018    NaN   8.1             NaN  Destino Rusia 2018
# 5   High Maintenance  2012    18+   8.2             NaN    High Maintenance
# 6               Rome  2012    NaN   5.8             NaN                Rome
#
#        tconst     titleType        primaryTitle       originalTitle  isAdult  \
# 0   tt3431720  tvMiniSeries    Jonah from Tonga    Jonah from Tonga      0.0
# 1   tt4725820      tvSeries        Magnífica 70        Magnífica 70      0.0
# 2   tt6329790      tvSeries   Vice News Tonight   Vice News Tonight      0.0
# 3  tt11212828      tvSeries           Todxs Nós           Todxs Nós      0.0
# 4   tt8367634  tvMiniSeries  Destino Rusia 2018  Destino Rusia 2018      0.0
# 5   tt2514438      tvSeries    High Maintenance    High Maintenance      0.0
# 6   tt2823184      tvSeries                Rome                Rome      0.0
#
#    startYear  endYear runtimeMinutes                   genres
# 0     2014.0   2014.0             30                   Comedy
# 1     2015.0   2015.0             60                    Drama
# 2     2016.0   2016.0             30                     News
# 3     2020.0   2020.0             \N                    Drama
# 4     2018.0   2018.0             30  Documentary,Drama,Sport
# 5     2012.0   2012.0             30                   Comedy
# 6     2012.0   2012.0             30     News,Sport,Talk-Show

# %%
hbo_ids = hbo_ids.append(hbo_missing).reset_index(drop=True).drop_duplicates("tconst")

# %%
hbo_ids
# Out:
#                   show  year rating  imdb rotten_tomatoes      tconst  \
# 0      Game of Thrones  2011    18+   9.3             89%   tt0944947
# 1             The Wire  2002    18+   9.3             94%   tt0306414
# 2            Chernobyl  2019    18+   9.4             96%   tt7366338
# 3         The Sopranos  1999    18+   9.2             92%   tt0141842
# 4     Band of Brothers  2001    18+   9.4             94%   tt0185906
# ..                 ...   ...    ...   ...             ...         ...
# 184  VICE News Tonight  2016    16+   8.3             NaN   tt6329790
# 185          Todxs Nos  2020    NaN   5.4             NaN  tt11212828
# 186      Destino Rusia  2018    NaN   8.1             NaN   tt8367634
# 187   High Maintenance  2012    18+   8.2             NaN   tt2514438
# 188               Rome  2012    NaN   5.8             NaN   tt2823184
#
#         titleType        primaryTitle       originalTitle  isAdult  ...  \
# 0        tvSeries     Game of Thrones     Game of Thrones      0.0  ...
# 1        tvSeries            The Wire            The Wire      0.0  ...
# 2    tvMiniSeries           Chernobyl           Chernobyl      0.0  ...
# 3        tvSeries        The Sopranos        The Sopranos      0.0  ...
# 4    tvMiniSeries    Band of Brothers    Band of Brothers      0.0  ...
# ..            ...                 ...                 ...      ...  ...
# 184      tvSeries   Vice News Tonight   Vice News Tonight      0.0  ...
# 185      tvSeries           Todxs Nós           Todxs Nós      0.0  ...
# 186  tvMiniSeries  Destino Rusia 2018  Destino Rusia 2018      0.0  ...
# 187      tvSeries    High Maintenance    High Maintenance      0.0  ...
# 188      tvSeries                Rome                Rome      0.0  ...
#
#                       genres  titleId ordering title region  language types  \
# 0     Action,Adventure,Drama      NaN      NaN   NaN    NaN       NaN   NaN
# 1       Crime,Drama,Thriller      NaN      NaN   NaN    NaN       NaN   NaN
# 2     Drama,History,Thriller      NaN      NaN   NaN    NaN       NaN   NaN
# 3                Crime,Drama      NaN      NaN   NaN    NaN       NaN   NaN
# 4       Action,Drama,History      NaN      NaN   NaN    NaN       NaN   NaN
# ..                       ...      ...      ...   ...    ...       ...   ...
# 184                     News      NaN      NaN   NaN    NaN       NaN   NaN
# 185                    Drama      NaN      NaN   NaN    NaN       NaN   NaN
# 186  Documentary,Drama,Sport      NaN      NaN   NaN    NaN       NaN   NaN
# 187                   Comedy      NaN      NaN   NaN    NaN       NaN   NaN
# 188     News,Sport,Talk-Show      NaN      NaN   NaN    NaN       NaN   NaN
#
#     attributes isOriginalTitle         imdb_titles
# 0          NaN             NaN                 NaN
# 1          NaN             NaN                 NaN
# 2          NaN             NaN                 NaN
# 3          NaN             NaN                 NaN
# 4          NaN             NaN                 NaN
# ..         ...             ...                 ...
# 184        NaN             NaN   Vice News Tonight
# 185        NaN             NaN           Todxs Nós
# 186        NaN             NaN  Destino Rusia 2018
# 187        NaN             NaN    High Maintenance
# 188        NaN             NaN                Rome
#
# [186 rows x 23 columns]

# %% [markdown]
# We will now calculate the ratio of titles with an imdb id match and the original titles.

# %%
len(hbo_ids)/len(hbo)
# Out:
# 0.93

# %% [markdown]
# This means that we will be using 94.5% of the original data.
#
# ### 5. Cleaning final data
#
# We will create a final data frame including:
# - show
# - year
# - rating
# - imdb
# - rotten_tomatoes
# - imdb_id
# - all data from title basics
#
# First, we will need to create the imdb_id column, this will have tconst and titleId values.

# %%
hbo_ids["imdb_id"] = np.where(hbo_ids["tconst"].isna(), hbo_ids["titleId"], hbo_ids["tconst"])

# %%
hbo_ids["imdb_id"].isna().value_counts()
# Out:
# False    186
# Name: imdb_id, dtype: int64

# %% [markdown]
# This means we have all the IMDB IDs for all the titles in this final data frame. We will now remove columns that are not show, year, rating, imdb, rotten_tomatoes and imdb_id and merge again.

# %%
to_drop = [col for col in hbo_ids.columns if col not in ["show", "year", "rating", "imdb", "rotten_tomatoes", "imdb_id"]]

# %%
hbo_ids = hbo_ids.drop(columns=to_drop)

# %%
hbo_ids.head()
# Out:
#                show  year rating  imdb rotten_tomatoes    imdb_id
# 0   Game of Thrones  2011    18+   9.3             89%  tt0944947
# 1          The Wire  2002    18+   9.3             94%  tt0306414
# 2         Chernobyl  2019    18+   9.4             96%  tt7366338
# 3      The Sopranos  1999    18+   9.2             92%  tt0141842
# 4  Band of Brothers  2001    18+   9.4             94%  tt0185906

# %% [markdown]
# Now we will merge all data from title basics

# %%
hbo_ids = hbo_ids.merge(imdb, how="left", left_on="imdb_id", right_on="tconst")

# %%
hbo_ids.head()
# Out:
#                show  year rating  imdb rotten_tomatoes    imdb_id     tconst  \
# 0   Game of Thrones  2011    18+   9.3             89%  tt0944947  tt0944947
# 1          The Wire  2002    18+   9.3             94%  tt0306414  tt0306414
# 2         Chernobyl  2019    18+   9.4             96%  tt7366338  tt7366338
# 3      The Sopranos  1999    18+   9.2             92%  tt0141842  tt0141842
# 4  Band of Brothers  2001    18+   9.4             94%  tt0185906  tt0185906
#
#       titleType      primaryTitle     originalTitle  isAdult  startYear  \
# 0      tvSeries   Game of Thrones   Game of Thrones        0     2011.0
# 1      tvSeries          The Wire          The Wire        0     2002.0
# 2  tvMiniSeries         Chernobyl         Chernobyl        0     2019.0
# 3      tvSeries      The Sopranos      The Sopranos        0     1999.0
# 4  tvMiniSeries  Band of Brothers  Band of Brothers        0     2001.0
#
#    endYear runtimeMinutes                  genres
# 0   2011.0             57  Action,Adventure,Drama
# 1   2002.0             59    Crime,Drama,Thriller
# 2   2019.0            330  Drama,History,Thriller
# 3   1999.0             55             Crime,Drama
# 4   2001.0            594    Action,Drama,History

# %% [markdown]
# ### 6. Export final data

# %%
# hbo_ids.to_pickle(path + "Data/hbo_final.pkl")
